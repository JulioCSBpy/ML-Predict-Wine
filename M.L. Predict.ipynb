# %%
import pandas as pd
arquivo = pd.read_csv('C:/Users/admin/Documents/ML/wine_dataset.csv')

# %%
arquivo.head()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality style
# 0      9.4        5   red
# 1      9.8        5   red
# 2      9.8        5   red
# 3      9.8        6   red
# 4      9.4        5   red

# %%
arquivo['style'] = arquivo['style'].replace('red', 0)

# %%
arquivo['style'] = arquivo['style'].replace('white', 1)

# %%
arquivo
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
#       free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 6492                 24.0                  92.0  0.99114  3.27       0.50
# 6493                 57.0                 168.0  0.99490  3.15       0.46
# 6494                 30.0                 111.0  0.99254  2.99       0.46
# 6495                 20.0                 110.0  0.98869  3.34       0.38
# 6496                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality  style
# 0         9.4        5      0
# 1         9.8        5      0
# 2         9.8        5      0
# 3         9.8        6      0
# 4         9.4        5      0
# ...       ...      ...    ...
# 6492     11.2        6      1
# 6493      9.6        5      1
# 6494      9.4        6      1
# 6495     12.8        7      1
# 6496     11.8        6      1
#
# [6497 rows x 13 columns]

# %%
y = arquivo['style']
x = arquivo.drop('style', axis = 1)

# %%
from sklearn.model_selection import train_test_split

# %%
x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.3)

# %%
from sklearn.ensemble import ExtraTreesClassifier
modelo = ExtraTreesClassifier()
modelo.fit(x_treino, y_treino)

resultado = modelo.score(x_teste, y_teste)
print('Acurácia', resultado)
# Out:
# Acurácia 0.9938461538461538

# %%
y_teste[52:57]
# Out:
# 950     0
# 4695    1
# 4034    1
# 3734    1
# 4659    1
# Name: style, dtype: int64

# %%
x_teste[52:57]
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 950             8.9              0.12         0.45             1.8      0.075
# 4695            6.8              0.13         0.39             1.4      0.034
# 4034            6.4              0.35         0.35             5.6      0.034
# 3734            7.2              0.16         0.26             7.1      0.054
# 4659            6.2              0.25         0.54             7.0      0.046
#
#       free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 950                  10.0                  21.0  0.99552  3.41       0.76
# 4695                 19.0                 102.0  0.99121  3.23       0.60
# 4034                  9.0                 148.0  0.99441  3.17       0.50
# 3734                 41.0                 224.0  0.99660  3.38       0.55
# 4659                 58.0                 176.0  0.99454  3.19       0.70
#
#       alcohol  quality
# 950      11.9        7
# 4695     11.3        7
# 4034      9.8        4
# 3734     10.1        5
# 4659     10.4        5

# %%
previsoes = modelo.predict(x_teste[52:57])
previsoes
# Out:
# array([0, 1, 1, 1, 1], dtype=int64)
